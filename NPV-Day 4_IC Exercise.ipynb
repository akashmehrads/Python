# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="10%">
#             <img src="in_class.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                   <b> Inclass - Lab <br> (Day 4) </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ##  Table of Content
#
# 1. **[Plots using Library Matplotlib ](#matplotlib)**
# 2. **[Plots using Library Seaborn ](#seaborn)**
# 3. **[Plots using Library Plotly](#plotly)**

# %% [markdown]
# ### Let us import the required libraries.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import plotly
import plotly.express as px

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id='matplotlib'></a>
# ## 1. Plots using Library Matplotlib

# %% [markdown]
# ### a. Scatter Plots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Plot a scatter plot for the following data. Also add title and axis names</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#             bmi = (18, 34, 54, 45, 45, 45, 23, 23, 54)
#             medical_claim = (145, 456, 764, 234, 156, 786, 345, 455, 675)

# %%
bmi = (18, 34, 54, 45, 45, 45, 23, 23, 54)
medical_claim = (145, 456, 764, 234, 156, 786, 345, 455, 675)

plt.scatter(x=bmi,y=medical_claim)
plt.xlabel('BMI')
plt.ylabel('Medical Claim')
plt.title("BMI to med claim chart")
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Write a code to get the following output </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# <img src="cos_curve.png" width = '500' >

# %%
x=np.arange(0,20,0.01)
y2=np.cos(0.3*np.pi*x)
plt.xlabel("x")
plt.ylabel("Cosine(x)")
plt.title("Cosine Curve")
plt.plot(x,y2)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Create a bubble plot. Further use the parameter 'alpha' to adjust the transparency level. (Generate the data using random number)</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# **Note:** A bubble chart is a type of scatter plot that represents three dimensional data. The third variable is represented by the size of a point (marker).

# %%
np.random.seed(23)
x1=np.random.randint(0,100,25)
x2=np.random.randint(0,100,25)

size=np.random.randint(0,100,25)

plt.scatter(x=x1,y=x2,s=size,alpha=0.5)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 4. Plot cosine curve and exponential curve for natural numbers from 0.1 to 20, in the same plot (get the following output)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# <img src="dual_axis.png" width ='500' >

# %%
x=np.arange(0,5,0.01)
y1=np.exp(x)
y2=np.cos(2*np.pi*x)

ax1=plt.gca()

ax2=ax1.twinx()

ax1.plot(x,y1)
ax2.plot(x,y2)
plt.show()

# %% [markdown]
# ### b. Barplots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 5. The exports and imports (in billion dollars) is given for a country from 2001 to 2005. Draw a barplot for the data
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
#   <tr>
#   <th>Year</th>
#   <th>Import</th>
#   <th>Export</th>
#   </tr>
#   <tr>
#   <td>2001</td>
#   <td>54.4</td>
#   <td>42.5 </td>
#   </tr>
#   <tr>
#   <td>2002</td>
#   <td>53.8</td>
#   <td>44.5</td>
#   </tr>
#   <tr>
#   <td>2003</td>
#   <td>61.6</td>
#   <td>48.3</td>
#   </tr>
#   <tr>
#   <td>2004</td>
#   <td>74.15</td>
#   <td>57.24</td>
#   </tr>
#   <tr>
#   <td>2005</td>
#   <td>89.33</td>
#   <td>69.18</td>
#   </tr>
# </table>

# %%
year = [2001,2002,2003,2004,2005]
imp = [54.4,53.8,61.6,74.15,89.33]
exp = [42.5,44.5,48.3,57.24,69.18]

plt.bar(x=year, height=imp)
plt.bar(x=year, height=exp, bottom=imp)
plt.show()

plt.bar(x=year, height=imp, width=0.4, align='edge')
plt.bar(x=year, height=exp,width=-0.4, align='edge')
plt.show()

# %% [markdown]
# ### c. Pie plots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 6. Plot a pie chart for the following data
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#         prices = [50, 25, 50, 20]
#         labels = ['Apple', 'Orange','Banana', 'Mango']

# %%
prices = [50, 25, 50, 20]
labels = ['Apple', 'Orange','Banana', 'Mango']


plt.pie(x=prices,labels=labels,autopct='%.2f')
plt.legend()
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 7. Following is the information release after the Indian budget is declared. Plot a donut chart for it
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
#   <tr>
#   <th>Income Form </th>
#   <th>Amount (in paise)</th>
#   </tr>
#   <tr>
#   <td>Corporation Tax</td>
#   <td>21</td>
#   </tr>
#   <tr>
#   <td>Income Tax</td>
#   <td>16</td>
#   </tr>
#   <tr>
#   <td>Customs</td>
#   <td>4</td>
#   </tr>
#   <tr>
#   <td>Union Excise Duties</td>
#   <td>8</td>
# </tr>
#   <tr>
#   <td>GST & Other Taxes</td>
#   <td>19</td>
# </tr>
# <tr>
#   <td>Non-Tax Revenue</td>
#   <td>9</td>
#   </tr>
#   <tr>
#   <td>Non-Debt Capital Receipts</td>
#   <td>3</td>
# </tr>
#   <tr>
#   <td>Borrowings and Other Liabilities</td>
#   <td>20</td>
#   </tr>
# </table>

# %%
d7={'Income_Form':['Coorp Tax','Income Tax','Customs','U Excise','GST & other tax','NontaxRev','NonDebtcapRecpts','Borrow&ottliabilites'],'Amount':[21,16,4,8,19,9,3,20]}
df7=pd.DataFrame(d7)
plt.pie(x=df7.Amount,labels=df7.Income_Form,autopct='%.2f')
circle=plt.Circle(xy=(0,0),radius=0.4,color='white')
ax=plt.gca()
ax.add_artist(circle)

plt.show()

# %% [markdown]
# ### d. Line plots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 8. Create a tuple of numbers 12, 34, 54, 45, 45, 45, 23, 23, 54 and plot a simple line plot
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
x=np.arange(0,9,1)
a=(12,34,54,45,45,45,23,23,54)

plt.plot(x,a,marker='*', linestyle='dotted')
plt.show()

ps1=pd.Series(a)
ps1.plot(kind='area')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 9. Import the 'Returns.csv'. Plot a multiple line plot for the returns of each company
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df9=pd.read_csv('NPV-Day 4_IC Data Table_Returns.csv')
print(df9.head())
for i in df9:
    df9[i].plot(kind='line',label=i)
plt.legend()
plt.show()
# Out:
#    Day       TCS  HDFCBANK  JINDALSTEL  TATAMOTORS      INFY  BOSCHLTD
# 0    1  1.439254 -0.425880   -0.496099    0.589743 -0.212106 -1.882246
# 1    2  1.382147 -1.650396   -0.421246    0.962322 -0.025425 -2.474510
# 2    3  0.921320 -0.208786   -0.452879    0.776448 -0.561877  1.556494
# 3    4 -0.572887 -0.315136   -0.364378    0.563103 -0.928679 -1.202984
# 4    5  1.275049  0.098216   -0.104096   -0.483990 -0.108262 -2.018111

# %%
df9=pd.read_csv('NPV-Day 4_IC Data Table_Returns.csv')
print(df9.drop(['Day'],axis=1))
df9.drop(['Day'],axis=1).plot(kind='line')
# Out:
#          TCS  HDFCBANK  JINDALSTEL  TATAMOTORS      INFY  BOSCHLTD
# 0   1.439254 -0.425880   -0.496099    0.589743 -0.212106 -1.882246
# 1   1.382147 -1.650396   -0.421246    0.962322 -0.025425 -2.474510
# 2   0.921320 -0.208786   -0.452879    0.776448 -0.561877  1.556494
# 3  -0.572887 -0.315136   -0.364378    0.563103 -0.928679 -1.202984
# 4   1.275049  0.098216   -0.104096   -0.483990 -0.108262 -2.018111
# 5  -0.328832  0.632894    0.325862    0.003768 -0.589602  2.494628
# 6  -0.146341  0.411697   -0.538937    0.117627  0.822381 -3.708947
# 7   1.058437 -1.158514    0.423811   -0.370031  0.361715 -1.617864
# 8  -0.111080 -1.159860    0.209816    0.174847  0.624075  2.360908
# 9  -0.038881 -0.689510    0.213396    0.135003  0.366363  5.610539
# 10 -0.322363 -1.052269   -0.101423   -0.039998 -0.160511  0.135336
# 11 -0.665766 -2.223733    0.076849   -0.119925  0.250447  1.918317
# 12 -0.704620 -0.656223    0.225169   -0.028262  0.259971 -2.093713
# ...

# %%
df9=pd.read_csv('NPV-Day 4_IC Data Table_Returns.csv', index_col=0)
print(df9.head())
df9.plot(kind='line')
# Out:
#           TCS  HDFCBANK  JINDALSTEL  TATAMOTORS      INFY  BOSCHLTD
# Day
# 1    1.439254 -0.425880   -0.496099    0.589743 -0.212106 -1.882246
# 2    1.382147 -1.650396   -0.421246    0.962322 -0.025425 -2.474510
# 3    0.921320 -0.208786   -0.452879    0.776448 -0.561877  1.556494
# 4   -0.572887 -0.315136   -0.364378    0.563103 -0.928679 -1.202984
# 5    1.275049  0.098216   -0.104096   -0.483990 -0.108262 -2.018111
# <AxesSubplot:xlabel='Day'>

# %%
df9=pd.read_csv('NPV-Day 4_IC Data Table_Returns.csv')
print(df9.head())
df9.iloc[:,1:].plot(kind='line')
# Out:
#    Day       TCS  HDFCBANK  JINDALSTEL  TATAMOTORS      INFY  BOSCHLTD
# 0    1  1.439254 -0.425880   -0.496099    0.589743 -0.212106 -1.882246
# 1    2  1.382147 -1.650396   -0.421246    0.962322 -0.025425 -2.474510
# 2    3  0.921320 -0.208786   -0.452879    0.776448 -0.561877  1.556494
# 3    4 -0.572887 -0.315136   -0.364378    0.563103 -0.928679 -1.202984
# 4    5  1.275049  0.098216   -0.104096   -0.483990 -0.108262 -2.018111
# <AxesSubplot:>

# %% [markdown]
# <a id='seaborn'></a>
# ## 2. Plots using Library Seaborn

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 10. Plot a  strip plot using inbuilt data-set 'iris' given in seaborn
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
df10=sns.load_dataset('iris')
df10.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.stripplot(data=df10,x='species',y='sepal_length' )
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 11. Import the dataset age_height.csv. Plot a heat map for the correlation matrix
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df11=pd.read_csv("NPV-Day 4_IC Data Table_age height.csv")
df11
cmatrix=df11.corr()

# %%
sns.heatmap(data=cmatrix)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 12. Plot a  swarmplot using inbuilt data-set 'iris' given in seaborn
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.swarmplot(data=df10, x='species',y='sepal_length')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 13a. Using the following data, plot a scatter plot with  the function available in seaborn
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#             x = (12, 34, 54, 45, 45, 45, 23, 23, 54)
#             y = (145, 456, 764, 234, 156, 786, 345, 455, 675)

# %%
x = (12, 34, 54, 45, 45, 45, 23, 23, 54)
y = (145, 456, 764, 234, 156, 786, 345, 455, 675)
sns.scatterplot(x=x,y=y)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 13b. Using the data generated in question 3, plot a scatter plot with the function available in seaborn
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
np.random.seed(23)
x1=np.random.randint(0,100,25)
x2=np.random.randint(0,100,25)

size=np.random.randint(0,100,25)

sns.scatterplot(x=x1,y=x2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 14. Using the 'diamonds' data available in the library seaborn, consider the price for the type of cut. Display the data using the following plots:
#                         <ol>
#                             <li> Multiple boxplot</li>
#                             <li> Violin Plot </li>
#                             <li> Boxen Plot </li>
#                         </ol>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df14=sns.load_dataset('diamonds')
df14.head()

print(pd.pivot_table(df14,index='cut',values='price',aggfunc=['min','mean','max']))
# Out:
#             min         mean    max
#           price        price  price
# cut
# Ideal       326  3457.541970  18806
# Premium     326  4584.257704  18823
# Very Good   336  3981.759891  18818
# Good        327  3928.864452  18788
# Fair        337  4358.757764  18574

# %%
#Multiple BoxPlot
sns.boxplot(data=df14,y='price',x='cut')
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
#Violin Plot
sns.violinplot(data=df14, x='cut',y='price')
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
#Boxenplot
sns.boxenplot(data=df14,x='cut',y='price')
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 15. Generate random number form normal distribution, plot the following:
#                         <ol>
#                             <li> Histogram</li>
#                             <li> Histogram with frequency curve </li>
#                         </ol>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
x1=np.random.randn(100)
x1
# Out:
# array([-1.33286349,  1.63739122, -0.82293868, -1.59810911,  0.22651174,
#         0.23389799, -0.94722245, -1.26157621, -2.38986578, -0.33327399,
#         0.34351676, -2.02786082,  0.13141631,  1.60323411, -1.76431364,
#         0.56650393,  0.54878807, -0.61513498,  0.32354564, -1.10319346,
#         0.45059596,  1.61745203, -0.34236494, -0.62348638, -2.01480815,
#         1.87089397,  1.8731981 , -0.50145597,  0.09009394, -0.09394458,
#         1.36048482, -1.56984254,  0.67640316, -2.25588661,  0.65361599,
#        -0.7458128 ,  1.30678324,  0.54931008, -0.61218062, -0.73684211,
#        -1.19535974,  1.68204548,  1.0654228 , -0.6055636 , -1.33355413,
#         0.49605774,  0.01319381, -0.48521005,  0.11583088,  0.66509522,
#        -0.0265563 ,  0.62321928, -0.00374142,  0.27196926, -0.54163878,
#         0.79379376,  0.15601287, -0.30459758,  0.18985569, -0.23206577,
#        -0.19035824,  0.52538404,  0.87305874, -1.63096187, -0.19005312,
# ...

# %%
sns.histplot(x1, bins=10)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(x1,bins=10,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# <a id='plotly'></a>
# ## 3. Plots using Library Plotly

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 16. Use the 'diamonds' data set from seaborn to plot the histogram of price by colors
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df16=sns.load_dataset('diamonds')
f=px.histogram(data_frame=df16,x='color',y='price')
f.show()
# Out:
# <div>                            <div id="7072880c-a8c1-4ff7-8fa5-3061c6d23f26" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7072880c-a8c1-4ff7-8fa5-3061c6d23f26")) {                    Plotly.newPlot(                        "7072880c-a8c1-4ff7-8fa5-3061c6d23f26",                        [{"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "color=%{x}<br>sum of price=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": ["E", "E", "E", "I", "J", "J", "I", "H", "E", "H", "J", "J", "F", "J", "E", "E", "I", "J", "J", "J", "I", "E", "H", "J", "J", "G", "I", "J", "D", "F", "F", "F", "E", "E", "D", "F", "E", "H
# ...

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 17. Plot a histrogram for 500 random numbers which have mean 0 and variance 1
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
anum=np.random.randn(500)
f=px.histogram(anum)
f.show()
# Out:
# <div>                            <div id="4c1cdd3a-1eef-4b5f-b033-d66bb48bb437" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c1cdd3a-1eef-4b5f-b033-d66bb48bb437")) {                    Plotly.newPlot(                        "4c1cdd3a-1eef-4b5f-b033-d66bb48bb437",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "variable=0<br>value=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "0", "marker": {"color": "#636efa"}, "name": "0", "offsetgroup": "0", "orientation": "v", "showlegend": true, "type": "histogram", "x": [-0.43076144495526375, 0.040866890147431965, -0.6980200272946478, 0.04623274405704249, -0.6568435072660898, -0.021419875437799978, 0.3324538943250397, -0.47520120304270475, -1.8656978718697104, 0.41
# ...

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 18. Using the 'tips' data from seaborn, plot a violin plot for 'tips' based on the 'sex'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df18=sns.load_dataset('tips')
df18.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
f=px.violin(data_frame=df18,x='sex',y='tip')
f.show()
# Out:
# <div>                            <div id="9766ee4d-bef2-4906-913a-0531e633b351" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9766ee4d-bef2-4906-913a-0531e633b351")) {                    Plotly.newPlot(                        "9766ee4d-bef2-4906-913a-0531e633b351",                        [{"alignmentgroup": "True", "box": {"visible": false}, "hovertemplate": "sex=%{x}<br>tip=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "scalegroup": "True", "showlegend": false, "type": "violin", "x": ["Female", "Male", "Male", "Male", "Female", "Male", "Male", "Male", "Male", "Male", "Male", "Female", "Male", "Male", "Female", "Male", "Female", "Male", "Female", "Male", "Male", "Female"
# ...

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 19. Using the tips dataset from seaborn, plot a donut plot with legend representing the percentage of the tip got on that day
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df19=sns.load_dataset('tips')
df19.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
f=px.pie(data_frame=df18, values='tip',names='day',hole=0.4)
f.show()
# Out:
# <div>                            <div id="4f215e55-31c4-440a-afcc-1ae0d29a73b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f215e55-31c4-440a-afcc-1ae0d29a73b8")) {                    Plotly.newPlot(                        "4f215e55-31c4-440a-afcc-1ae0d29a73b8",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hole": 0.4, "hovertemplate": "day=%{label}<br>tip=%{value}<extra></extra>", "labels": ["Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Su
# ...

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 20. The exports and imports (in billion dollars) is given for a country from 2001 to 2005. Draw a barplot for the data
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
#   <tr>
#   <th>Year</th>
#   <th>Import</th>
#   <th>Export</th>
#   </tr>
#   <tr>
#   <td>2001</td>
#   <td>54.4</td>
#   <td>42.5 </td>
#   </tr>
#   <tr>
#   <td>2002</td>
#   <td>53.8</td>
#   <td>44.5</td>
#   </tr>
#   <tr>
#   <td>2003</td>
#   <td>61.6</td>
#   <td>48.3</td>
#   </tr>
#   <tr>
#   <td>2004</td>
#   <td>74.15</td>
#   <td>57.24</td>
#   </tr>
#   <tr>
#   <td>2005</td>
#   <td>89.33</td>
#   <td>69.18</td>
#   </tr>
# </table>

# %%
d20={'Year':[2001,2002,2003,2004,2005],'Import':[54.4,53.8,61.6,74.15,89.33],
    'Export':[42.5,44.5,48.3,57.24,69.18]}
df20=pd.DataFrame(d20)
df20
# Out:
#    Year  Import  Export
# 0  2001   54.40   42.50
# 1  2002   53.80   44.50
# 2  2003   61.60   48.30
# 3  2004   74.15   57.24
# 4  2005   89.33   69.18

# %%
f=px.bar(data_frame=df20,x='Year',y=['Import','Export'],barmode='group')
f.show()
# Out:
# <div>                            <div id="3d48ae69-5415-4e64-92e9-13e84823ddc7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d48ae69-5415-4e64-92e9-13e84823ddc7")) {                    Plotly.newPlot(                        "3d48ae69-5415-4e64-92e9-13e84823ddc7",                        [{"alignmentgroup": "True", "hovertemplate": "variable=Import<br>Year=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Import", "marker": {"color": "#636efa"}, "name": "Import", "offsetgroup": "Import", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2001, 2002, 2003, 2004, 2005], "xaxis": "x", "y": [54.4, 53.8, 61.6, 74.15, 89.33], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "variable=Export<br>Year=%{x}<br>v
# ...
