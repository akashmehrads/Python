# %%
 # Read the dataset and do primary study of data. Perform following steps: 
 # a. Reading some rows of dataset
 # b. Learn data types of all features
 # c. See the statistical properties of the data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dfemp=pd.read_csv('emp_health.csv')
dfemp
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 0     i10012   19  female  27.900          0    daily   yes  southwest
# 1     i10013   18    male  33.770          1  weekend    no      south
# 2     i10014   28    male  33.000          3   rarely    no      south
# 3     i10015   33    male  22.705          0    daily    no  northwest
# 4     i10016   32    male  28.880          0    party    no  northwest
# ...      ...  ...     ...     ...        ...      ...   ...        ...
# 1333  i11345   50    male  30.970          3       no    no       west
# 1334  i11346   18  female  31.920          0    daily    no       east
# 1335  i11347   18  female  36.850          0  weekend    no  southeast
# 1336  i11348   21  female  25.800          0    party    no  southwest
# 1337  i11349   61  female  29.070          0       no   yes       west
#
#       expenditure
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# ...

# %%
# a. Reading some rows of dataset
print(dfemp.iloc[0])
print()
print(dfemp.iloc[5])
print()
print(dfemp.iloc[1000])
print()
print(dfemp.iloc[1337])
# Out:
# id                i10012
# age                   19
# sex               female
# bmi                 27.9
# dependent              0
# alcohol            daily
# smoke                yes
# zone           southwest
# expenditure      16884.9
# Name: 0, dtype: object
#
# id              i10017
# age                 31
# sex             female
# bmi              25.74
# dependent            0
# alcohol             no
# smoke               no
# zone             south
# expenditure    3756.62
# Name: 5, dtype: object
#
# id              i11012
# age                 30
# sex               male
# bmi              22.99
# dependent            2
# alcohol          party
# smoke              yes
# zone              west
# expenditure    17361.8
# Name: 1000, dtype: object
#
# id              i11349
# age                 61
# sex             female
# bmi              29.07
# dependent            0
# alcohol             no
# smoke              yes
# zone              west
# ...

# %%
# b. Learn data types of all features
print('DataFrame= ',type(dfemp))
print('Id= ',type(dfemp.id))
print('Age= ',type(dfemp.age))
print('Sex= ',type(dfemp.sex))
print('BMI= ',type(dfemp.bmi))
print('Dependent= ',type(dfemp.dependent))
print('Alcohol= ',type(dfemp.alcohol))
print('Smoke= ',type(dfemp.smoke))
print('Zone= ',type(dfemp.zone))
print('Expenditure= ',type(dfemp.expenditure))
# Out:
# DataFrame=  <class 'pandas.core.frame.DataFrame'>
# Id=  <class 'pandas.core.series.Series'>
# Age=  <class 'pandas.core.series.Series'>
# Sex=  <class 'pandas.core.series.Series'>
# BMI=  <class 'pandas.core.series.Series'>
# Dependent=  <class 'pandas.core.series.Series'>
# Alcohol=  <class 'pandas.core.series.Series'>
# Smoke=  <class 'pandas.core.series.Series'>
# Zone=  <class 'pandas.core.series.Series'>
# Expenditure=  <class 'pandas.core.series.Series'>

# %%
# c. See the statistical properties of the data.
dfemp.describe()             #statistical data only for numeric data columns
# Out:
#                age          bmi    dependent   expenditure
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# Q1. How many employees above 50 age smoke, what is their average expenditure on health management?

dfage_smoke=dfemp[(dfemp.smoke=='yes') & (dfemp.age>50)]
print('Number of employees above 50 yrs of age and smoke= ',len(dfage_smoke))
# Out:
# Number of employees above 50 yrs of age and smoke=  64

# %%
# what is their average expenditure on health management?

print(dfage_smoke)
dfp=pd.pivot_table(dfage_smoke,index='expenditure',aggfunc='mean')
print(dfp)
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 11    i10023   62  female  26.290          0    daily   yes      south
# 39    i10051   60    male  39.900          0    daily   yes  southwest
# 55    i10067   58    male  36.955          2  weekend   yes  northwest
# 58    i10070   53  female  22.880          1    daily   yes      south
# 86    i10098   57  female  31.160          0       no   yes  northwest
# ...      ...  ...     ...     ...        ...      ...   ...        ...
# 1265  i11277   64    male  23.760          0  weekend   yes  southeast
# 1284  i11296   61    male  36.300          1    daily   yes  southwest
# 1301  i11313   62    male  30.875          3       no   yes       west
# 1321  i11333   62    male  26.695          0    daily   yes       east
# 1337  i11349   61  female  29.070          0       no   yes       west
#
#       expenditure
# 11    27808.72510
# 39    48173.36100
# 55    47496.49445
# 58    23244.79020
# ...

# %%
# Q2. How many female employees did not consume alcohol daily. What is their proportion with respect to total female employees?

# %%
df_female=dfemp[(dfemp.sex=='female') & (dfemp.alcohol!='daily')]
print(df_female)
print()
print('Number of female employees who did not consume alcohol daily= ',len(df_female))
# Out:
#           id  age     sex    bmi  dependent  alcohol smoke       zone  \
# 5     i10017   31  female  25.74          0       no    no      south
# 7     i10019   37  female  27.74          3  weekend    no  northwest
# 9     i10021   60  female  25.84          0       no    no  northwest
# 13    i10025   56  female  39.82          0  weekend    no      south
# 16    i10028   52  female  30.78          1    party    no      north
# ...      ...  ...     ...    ...        ...      ...   ...        ...
# 1330  i11342   57  female  25.74          2       no    no  southeast
# 1332  i11344   52  female  44.70          3    party    no  southwest
# 1335  i11347   18  female  36.85          0  weekend    no  southeast
# 1336  i11348   21  female  25.80          0    party    no  southwest
# 1337  i11349   61  female  29.07          0       no   yes       west
#
#       expenditure
# 5      3756.62160
# 7      7281.50560
# 9     28923.13692
# 13    11090.71780
# 16    10797.33620
# ...

# %%
# What is their proportion with respect to total female employees?
df_tot_female=df1[dfemp.sex=='female']
print('Total number of females= ',len(df_tot_female))
print('Total number of females who do not consume alocohol dialy= ',len(df_female))
print('Proportion= ',len(df_female)/len(df_tot_female))
# Out:
# Total number of females=  662
# Total number of females who do not consume alocohol dialy=  453
# Proportion=  0.6842900302114804

# %%
# Q3. Display zone wise average expenditure of employees on health
pd.pivot_table(dfemp,index='zone',aggfunc='mean',values='expenditure')
# Out:
#             expenditure
# zone
# east       13774.679941
# north      14102.583403
# northeast  13694.721724
# northwest  12151.702619
# south      14715.689519
# southeast  14452.949680
# southwest  12717.083869
# west       12182.998872

# %%
# Q4. Employees of which zone did maximum expenditure on health

df_max_exp=pd.pivot_table(dfemp,index='zone',aggfunc='max',values='expenditure')
print(df_max_exp)
print()
max=df_max_exp.max()
                  #df2=df_max_exp[df_max_exp==max]
                  #print(df2)
print('Employees with Maximum expenditure= ',max)
df4=dfemp.loc[dfemp.expenditure == dfemp.expenditure.max(), 'zone']
df4
# Out:
#            expenditure
# zone
# east       58571.07448
# north      48549.17835
# northeast  46255.11250
# northwest  55135.40209
# south      47055.53210
# southeast  63770.42801
# southwest  52590.82939
# west       60021.39897
#
# Employees with Maximum expenditure=  expenditure    63770.42801
# dtype: float64
# 543    southeast
# Name: zone, dtype: object

# %%
# Q5. What is the minimum expenditure done by any employee in organization

df_min_exp=pd.pivot_table(dfemp,index='expenditure',aggfunc='min')
print(df_min_exp)
print()
min=df_min_exp.min()
print('Employee with Minimum expenditure= ',min)
# Out:
#              age  alcohol     bmi  dependent      id     sex smoke       zone
# expenditure
# 1121.87390    18    party  23.210          0  i10952    male    no  southeast
# 1131.50660    18    daily  30.140          0  i10820    male    no       east
# 1135.94070    18   rarely  33.330          0  i11256    male    no  southeast
# 1136.39940    18    daily  33.660          0  i10675    male    no       east
# 1137.01100    18    daily  34.100          0  i10034    male    no      south
# ...          ...      ...     ...        ...     ...     ...   ...        ...
# 55135.40209   33    daily  35.530          0  i10831  female   yes  northwest
# 58571.07448   31    daily  38.095          1  i10589  female   yes       east
# 60021.39897   52  weekend  34.485          3  i11242    male   yes       west
# 62592.87309   45    party  30.360          0  i11312    male   yes  southeast
# 63770.42801   54    party  47.410          0  i10555  female   yes  southeast
#
# ...

# %%
# Q6. What is average expenditure of employees who have 2 or lesser dependents

print(dfemp[(dfemp.dependent==0) | (dfemp.dependent==1) | (dfemp.dependent==2)])
print()
df_exp_dep=dfemp[(dfemp.dependent==0) | (dfemp.dependent==1) | (dfemp.dependent==2)]
dfp=pd.pivot_table(df_exp_dep,index='dependent',aggfunc='mean',values='expenditure')
print('Average expenditure for employees with 2 or less dependents:: ')
print(dfp)
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 0     i10012   19  female  27.900          0    daily   yes  southwest
# 1     i10013   18    male  33.770          1  weekend    no      south
# 3     i10015   33    male  22.705          0    daily    no  northwest
# 4     i10016   32    male  28.880          0    party    no  northwest
# 5     i10017   31  female  25.740          0       no    no      south
# ...      ...  ...     ...     ...        ...      ...   ...        ...
# 1331  i11343   23  female  33.400          0    daily    no  southwest
# 1334  i11346   18  female  31.920          0    daily    no       east
# 1335  i11347   18  female  36.850          0  weekend    no  southeast
# 1336  i11348   21  female  25.800          0    party    no  southwest
# 1337  i11349   61  female  29.070          0       no   yes       west
#
#       expenditure
# 0     16884.92400
# 1      1725.55230
# 3     21984.47061
# 4      3866.85520
# ...

# %%
# Q7. How many employees are below age of 20 years. What is their average BMI
df_age_20=dfemp[dfemp.age<20]
print('Number of Employees that are below the age of 20 years= ',len(df_age_20))
print()
print('Average BMI::')
dfp=pd.pivot_table(df_age_20,index='age',aggfunc='mean',values='bmi')
print(dfp)
# Out:
# Number of Employees that are below the age of 20 years=  137
#
# Average BMI::
#            bmi
# age
# 18   31.326159
# 19   28.596912

# %%
# Q8. Create a dataframe "non_smoker" for all non-smoker male employees
df_non_smoker=dfemp[(dfemp.smoke=='no') & (dfemp.sex=='male')]
df_non_smoker
# Out:
#           id  age   sex     bmi  dependent  alcohol smoke       zone  \
# 1     i10013   18  male  33.770          1  weekend    no      south
# 2     i10014   28  male  33.000          3   rarely    no      south
# 3     i10015   33  male  22.705          0    daily    no  northwest
# 4     i10016   32  male  28.880          0    party    no  northwest
# 8     i10020   37  male  29.830          2    party    no      north
# ...      ...  ...   ...     ...        ...      ...   ...        ...
# 1324  i11336   31  male  25.935          1    daily    no       west
# 1325  i11337   61  male  33.535          0    party    no       east
# 1327  i11339   51  male  30.030          1    daily    no  southeast
# 1329  i11341   52  male  38.600          2    party    no  southwest
# 1333  i11345   50  male  30.970          3       no    no       west
#
#       expenditure
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# 8      6406.41070
# ...           ...
# ...

# %%
# Q9. Create a dataframe "non_alcoholic" for all male employees who do not consume alcohol
df_non_alcoholic=dfemp[(dfemp.sex=='male') & (dfemp.alcohol=='no')]
df_non_alcoholic
# Out:
#           id  age   sex     bmi  dependent alcohol smoke       zone  \
# 18    i10030   56  male  40.300          0      no    no  southwest
# 24    i10036   37  male  28.025          2      no    no  northwest
# 28    i10040   23  male  17.385          1      no    no  northwest
# 37    i10049   26  male  20.800          0      no    no  southwest
# 38    i10050   35  male  36.670          1      no   yes      north
# ...      ...  ...   ...     ...        ...     ...   ...        ...
# 1291  i11303   19  male  34.900          0      no   yes  southwest
# 1301  i11313   62  male  30.875          3      no   yes       west
# 1310  i11322   42  male  26.315          1      no    no       west
# 1320  i11332   31  male  31.065          3      no    no       west
# 1333  i11345   50  male  30.970          3      no    no       west
#
#       expenditure
# 18    10602.38500
# 24     6203.90175
# 28     2775.19215
# 37     2302.30000
# 38    39774.27630
# ...           ...
# ...

# %%
# Q10. Create a dataframe called "non_smoking_alcoholic" with the men employees who do not smoke and consume alcohol. The dataframe should contain columns id, smoke, alcohol

df_non_s_a=pd.merge(df_non_smoker,df_non_alcoholic, on='id', how='inner')
df_non_smooking_alcoholic=df_non_s_a.drop(['age_x','sex_x','zone_x','expenditure_x','bmi_x','dependent_x','age_y','sex_y','zone_y','expenditure_y','bmi_y','dependent_y'],axis=1)
print(df_non_smooking_alcoholic)
# Out:
#          id alcohol_x smoke_x alcohol_y smoke_y
# 0    i10030        no      no        no      no
# 1    i10036        no      no        no      no
# 2    i10040        no      no        no      no
# 3    i10049        no      no        no      no
# 4    i10079        no      no        no      no
# ..      ...       ...     ...       ...     ...
# 104  i11273        no      no        no      no
# 105  i11282        no      no        no      no
# 106  i11322        no      no        no      no
# 107  i11332        no      no        no      no
# 108  i11345        no      no        no      no
#
# [109 rows x 5 columns]

# %%
# Q11. What is the count for each zone with respect to number of dependent

df_zone=pd.pivot_table(dfemp,index='zone',aggfunc='sum',values='dependent')    
print('Count for each zone with respect to the number of dependents::')
print(df_zone)
# Out:
# Count for each zone with respect to the number of dependents::
#            dependent
# zone
# east             254
# north             85
# northeast         86
# northwest        143
# south             85
# southeast        211
# southwest        275
# west             326

# %%
# Q12. Classify the employees into 3 categories.
 #a-Category 1 : employees below 18.5 bmi - underweight
 #b-Category 2 : employees with bmi in the range of 18.5 to 24.9 - fit
 #c-Category 3 : employee with bmi over 24.9 - overweight
 #d-What is the average expenditure of employees in each category.

# %%
#a-Category 1 : employees below 18.5 bmi - underweight
df_under_weight=dfemp[dfemp.bmi<18.5]
print(df_under_weight.head())
# Out:
#          id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 28   i10040   23    male  17.385          1       no    no  northwest
# 128  i10140   32  female  17.765          2  weekend   yes  northwest
# 172  i10184   18    male  15.960          0    party    no      north
# 198  i10210   51  female  18.050          0  weekend    no  northwest
# 232  i10244   19  female  17.800          0    party    no  southwest
#
#      expenditure
# 28    2775.19215
# 128  32734.18630
# 172   1694.79640
# 198   9644.25250
# 232   1727.78500

# %%
#b-Category 2 : employees with bmi in the range of 18.5 to 24.9 - fit
df_fit=dfemp[(dfemp.bmi>18.5)&(dfemp.bmi<24.9)]
print(df_fit.head())
# Out:
#         id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 3   i10015   33    male  22.705          0    daily    no  northwest
# 15  i10027   19    male  24.600          1    party    no  southwest
# 17  i10029   23    male  23.845          0  weekend    no      north
# 26  i10038   63  female  23.085          0  weekend    no      north
# 35  i10047   19    male  20.425          0    party    no  northwest
#
#     expenditure
# 3   21984.47061
# 15   1837.23700
# 17   2395.17155
# 26  14451.83515
# 35   1625.43375

# %%
#c-Category 3 : employee with bmi over 24.9 - overweight
df_over_weight=dfemp[dfemp.bmi>24.9]
print(df_over_weight.head())
# Out:
#        id  age     sex    bmi  dependent  alcohol smoke       zone  \
# 0  i10012   19  female  27.90          0    daily   yes  southwest
# 1  i10013   18    male  33.77          1  weekend    no      south
# 2  i10014   28    male  33.00          3   rarely    no      south
# 4  i10016   32    male  28.88          0    party    no  northwest
# 5  i10017   31  female  25.74          0       no    no      south
#
#    expenditure
# 0   16884.9240
# 1    1725.5523
# 2    4449.4620
# 4    3866.8552
# 5    3756.6216

# %%
#d-What is the average expenditure of employees in each category.

#FOR CATEGORY UNDER WEIGHT:
mean=df_under_weight.expenditure.mean()
print('Average expenditure of Under Weight employees= ',mean)
print()
#FOR CATEGORY FIT:
mean1=df_fit.expenditure.mean()
print('Average expenditure of Fit employees= ',mean1)
print()
#FOR CATEGORY OVER WEIGHT:
mean2=df_over_weight.expenditure.mean()
print('Average expenditure of Over Weight employees= ',mean2)
# Out:
# Average expenditure of Under Weight employees=  8852.200585000002
#
# Average expenditure of Fit employees=  10404.900083891405
#
# Average expenditure of Over Weight employees=  13936.616823466235

# %%
# Q13. Draw line plot of expenditure against age and BMI
plt.plot(dfemp.expenditure,dfemp.age,marker='*',color='pink',label='age')
plt.plot(dfemp.expenditure,dfemp.bmi,marker='>',color='blue',label='bmi')
plt.xlabel('Expenditure')
plt.legend()
plt.show()

# %%
# Q14. Draw a bar chart to show zone wise average expenditure
dfz=pd.pivot_table(dfemp,index='zone',values='expenditure',aggfunc='mean')
print(dfz)
dfz.plot.bar(color='m')
# Out:
#             expenditure
# zone
# east       13774.679941
# north      14102.583403
# northeast  13694.721724
# northwest  12151.702619
# south      14715.689519
# southeast  14452.949680
# southwest  12717.083869
# west       12182.998872
# <AxesSubplot:xlabel='zone'>

# %%
# Q15. Draw a bar chart to show smoking and alcoholic habits against average expenditure

df_smoke=pd.pivot_table(dfemp,index='smoke',values='expenditure',aggfunc='mean')
print(df_smoke)
df_alcohol=pd.pivot_table(dfemp,index='alcohol',values='expenditure',aggfunc='mean')
print(df_alcohol)
df_smoke.plot.bar(color='blue')
df_alcohol.plot.bar(color='yellow')
# Out:
#         expenditure
# smoke
# no      8434.268298
# yes    32050.231832
#           expenditure
# alcohol
# daily    13001.772968
# no       14277.090885
# party    13050.583157
# rarely   12419.686784
# weekend  13145.632539
# <AxesSubplot:xlabel='alcohol'>

# %%
# Q15. Draw pie chart for alcohol consumption habits
vc=dfemp.alcohol.value_counts()
print(vc)
plt.pie(x=vc.values,autopct='%.2f',labels=vc.index)
plt.show()
# Out:
# daily      395
# weekend    347
# party      278
# no         259
# rarely      59
# Name: alcohol, dtype: int64

# %%
# Q17. Draw scatterplot to see the relation between age and expenditure, keep smoking habit as hue
import seaborn as sns

sns.scatterplot(x=dfemp.age,y=dfemp.expenditure,hue=dfemp.smoke)
# Out:
# <AxesSubplot:xlabel='age', ylabel='expenditure'>

# %%
# Q18. Draw distribution plot of expenditure
sns.distplot(dfemp.expenditure)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='expenditure', ylabel='Density'>

# %%
# Q19. Display the pairplot
sns.pairplot(dfemp)

# %%
# Q20. Display heatmap for the data
cmatrix=dfemp.corr()
sns.heatmap(cmatrix,annot=True,cmap='plasma')
# Out:
# <AxesSubplot:>
